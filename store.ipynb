# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
url = 'https://dkankutb.com/category/OqRYw'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html dir="rtl" lang="ar">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no" name="viewport"/>
# <meta content="#fff3d9" name="theme-color"/>
# <meta content="#fff3d9" name="msapplication-navbutton-color"/>
# <meta content="#fff3d9" name="apple-mobile-web-app-status-bar-style"/>
# <link href="https://cdn.salla.sa/XRQB/jngyFxn4pZDK8ZKCfhVytKTeBkzOXagSQ5ZFyqFp.jpg" rel="icon" type="image/png"/>
# <link href="https://cdn.salla.sa/XRQB/jngyFxn4pZDK8ZKCfhVytKTeBkzOXagSQ5ZFyqFp.jpg" rel="apple-touch-icon-precomposed"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="https://cdn.salla.sa/XRQB/jngyFxn4pZDK8ZKCfhVytKTeBkzOXagSQ5ZFyqFp.jpg" name="msapplication-TileImage"/>
# <meta content="g3xIiZmhdxyr1rh62IHZTML8iTyxT6oqvzF9ac2Z" name="_token"/>
# <title>كتب أطفال - دكان كتب</title>
# ...

# %%
divs = soup.find_all('div', {'class':'product'})
divs
# Out:
# [<div class="product">
#  <a href="https://dkankutb.com/RvlmyD" rel="canonical">
#  <span class="img-cont">
#  <img alt="كل شبر بنذر" class="lazyload" data-src="https://cdn.salla.sa/PCXUZJcazjRx8FOGJMuWulDK6fb0meiuQxvlseuY.jpeg" src="https://cdn.assets.salla.network/stores/themes/default/assets/images/product-loading.png?v=v1.5.533"/>
#  </span>
#  <h3 class="product-title">كل شبر بنذر</h3>
#  </a>
#  <div class="product-footer" style="margin-top: auto">
#  <p class="product-price"> <span class="price-before">65 ر.س</span><span class="price-after">45 ر.س</span> </p>
#  <a class="product-add add_to_cart_btn" data-currency="SAR" data-is-donation="" data-price="45" data-product-id="82552275" data-product-type="product" href="#add_to_cart" rel="nofollow">
#  <span class="sicon-cart"></span>
#  <span>إضافة للسلة</span>
#  </a>
#  </div>
#  </div>,
#  <div class="product">
#  <a href="https://dkankutb.com/wAyEem" rel="canonical">
#  <span class="img-cont">
# ...

# %%
divs1 = soup.find_all('div', {'class':'product'})
divs1
# Out:
# [<div class="product">
#  <a href="https://dkankutb.com/RvlmyD" rel="canonical">
#  <span class="img-cont">
#  <img alt="كل شبر بنذر" class="lazyload" data-src="https://cdn.salla.sa/PCXUZJcazjRx8FOGJMuWulDK6fb0meiuQxvlseuY.jpeg" src="https://cdn.assets.salla.network/stores/themes/default/assets/images/product-loading.png?v=v1.5.533"/>
#  </span>
#  <h3 class="product-title">كل شبر بنذر</h3>
#  </a>
#  <div class="product-footer" style="margin-top: auto">
#  <p class="product-price"> <span class="price-before">65 ر.س</span><span class="price-after">45 ر.س</span> </p>
#  <a class="product-add add_to_cart_btn" data-currency="SAR" data-is-donation="" data-price="45" data-product-id="82552275" data-product-type="product" href="#add_to_cart" rel="nofollow">
#  <span class="sicon-cart"></span>
#  <span>إضافة للسلة</span>
#  </a>
#  </div>
#  </div>,
#  <div class="product">
#  <a href="https://dkankutb.com/wAyEem" rel="canonical">
#  <span class="img-cont">
# ...

# %%
#divs[0].find_all('div', {'class':'col-xs-6 col-sm-4 col-lg-3 product-box'},{'class':'product contain'}),('h3', {'class':'product-title'}),('div', {'class':'product-footer'}),('p', {'class':'product-price'})

# %%
#divs[0].find_all('h3', {'class':'product-title'})

# %%
#divs[0].find_all('div', {'class':'product-footer'})
                 
    #,{'class':'product-price'}

# %%
#divs[0].find_all('p', {'class':'product-price'})

# %%
divs[0].find('a')
# Out:
# <a href="https://dkankutb.com/RvlmyD" rel="canonical">
# <span class="img-cont">
# <img alt="كل شبر بنذر" class="lazyload" data-src="https://cdn.salla.sa/PCXUZJcazjRx8FOGJMuWulDK6fb0meiuQxvlseuY.jpeg" src="https://cdn.assets.salla.network/stores/themes/default/assets/images/product-loading.png?v=v1.5.533"/>
# </span>
# <h3 class="product-title">كل شبر بنذر</h3>
# </a>

# %%
headings = [div.find('a')for div in divs]
headings
# Out:
# [<a href="https://dkankutb.com/RvlmyD" rel="canonical">
#  <span class="img-cont">
#  <img alt="كل شبر بنذر" class="lazyload" data-src="https://cdn.salla.sa/PCXUZJcazjRx8FOGJMuWulDK6fb0meiuQxvlseuY.jpeg" src="https://cdn.assets.salla.network/stores/themes/default/assets/images/product-loading.png?v=v1.5.533"/>
#  </span>
#  <h3 class="product-title">كل شبر بنذر</h3>
#  </a>,
#  <a href="https://dkankutb.com/wAyEem" rel="canonical">
#  <span class="img-cont">
#  <img alt="ذكي ولكن مشتت" class="lazyload" data-src="https://cdn.salla.sa/hYlDFOlV9OFtbZhq05lRRpuUCFHCjpJQvS3Jpf8L.jpeg" src="https://cdn.assets.salla.network/stores/themes/default/assets/images/product-loading.png?v=v1.5.533"/>
#  </span>
#  <h3 class="product-title">ذكي ولكن مشتت</h3>
#  </a>,
#  <a href="https://dkankutb.com/yKvxpl" rel="canonical">
#  <span class="img-cont">
# ...

# %%
headings[0]
# Out:
# <a href="https://dkankutb.com/RvlmyD" rel="canonical">
# <span class="img-cont">
# <img alt="كل شبر بنذر" class="lazyload" data-src="https://cdn.salla.sa/PCXUZJcazjRx8FOGJMuWulDK6fb0meiuQxvlseuY.jpeg" src="https://cdn.assets.salla.network/stores/themes/default/assets/images/product-loading.png?v=v1.5.533"/>
# </span>
# <h3 class="product-title">كل شبر بنذر</h3>
# </a>

# %%
[heading.find('h3') for heading in headings]
# Out:
# [<h3 class="product-title">كل شبر بنذر</h3>,
#  <h3 class="product-title">ذكي ولكن مشتت</h3>,
#  <h3 class="product-title">الامير الصغير</h3>,
#  <h3 class="product-title">حكايات القط الشقي 1/2</h3>,
#  <h3 class="product-title">الأمير الصغير</h3>,
#  <h3 class="product-title">مذكرات طالب العجلة الثالثة</h3>,
#  <h3 class="product-title">مذكرات طالب الحقيقة المرة</h3>,
#  <h3 class="product-title">مذكرات طالب الحظ العاثر</h3>,
#  <h3 class="product-title">مذكرات طالب القشة الاخيرة</h3>,
#  <h3 class="product-title">مذكرات طالب جنون المنزل</h3>,
#  <h3 class="product-title">مذكرات طالب قوانين الاخ الاكبر</h3>,
#  <h3 class="product-title">مذكرات طالب الرحلة الشاقة</h3>,
#  <h3 class="product-title">مذكرات طالب الخطة الفاشلة</h3>,
#  <h3 class="product-title">مذكرات طالب</h3>,
#  <h3 class="product-title">مذكرات طالب بقلمك انت</h3>,
#  <h3 class="product-title">مذكرات طالب ايام زمان</h3>,
#  <h3 class="product-title">مذكرات طالب ايام الكلاب</h3>,
# ...

# %%
store_names = [heading.find('h3').string for heading in headings] 
store_names
# Out:
# ['كل شبر بنذر',
#  'ذكي ولكن مشتت',
#  'الامير الصغير',
#  'حكايات القط الشقي 1/2',
#  'الأمير الصغير',
#  'مذكرات طالب العجلة الثالثة',
#  'مذكرات طالب الحقيقة المرة',
#  'مذكرات طالب الحظ العاثر',
#  'مذكرات طالب القشة الاخيرة',
#  'مذكرات طالب جنون المنزل',
#  'مذكرات طالب قوانين الاخ الاكبر',
#  'مذكرات طالب الرحلة الشاقة',
#  'مذكرات طالب الخطة الفاشلة',
#  'مذكرات طالب',
#  'مذكرات طالب بقلمك انت',
#  'مذكرات طالب ايام زمان',
#  'مذكرات طالب ايام الكلاب',
#  'كخه يا بايا',
#  'وصايا',
#  'رحلة الى اليابان',
#  'الاطفال من الجنة',
#  'مع خاتم الانبياء',
#  'مع صحابة نبينا الحبيب',
#  'كتاب ينقذ طفلا',
#  'رحلة حمار حول العالم']

# %%
divs1[0].find('p')
# Out:
# <p class="product-price"> <span class="price-before">65 ر.س</span><span class="price-after">45 ر.س</span> </p>

# %%
h=[div.find('p')for div in divs1]
h
# Out:
# [<p class="product-price"> <span class="price-before">65 ر.س</span><span class="price-after">45 ر.س</span> </p>,
#  <p class="product-price"> <span class="price-before">60 ر.س</span><span class="price-after">45 ر.س</span> </p>,
#  <p class="product-price"> <span class="product-price" dir="ltr"> 38 ر.س</span> </p>,
#  <p class="product-price"> <span class="product-price" dir="ltr"> 60 ر.س</span> </p>,
#  <p class="product-price"> <span class="product-price" dir="ltr"> 15 ر.س</span> </p>,
#  <p class="product-price"> <span class="product-price" dir="ltr"> 35 ر.س</span> </p>,
#  <p class="product-price"> <span class="product-price" dir="ltr"> 35 ر.س</span> </p>,
#  <p class="product-price"> <span class="product-price" dir="ltr"> 35 ر.س</span> </p>,
#  <p class="product-price"> <span class="product-price" dir="ltr"> 35 ر.س</span> </p>,
#  <p class="product-price"> <span class="product-price" dir="ltr"> 35 ر.س</span> </p>,
# ...

# %%
q=h[2]
q
# Out:
# <p class="product-price"> <span class="product-price" dir="ltr"> 38 ر.س</span> </p>

# %%
[heading.find('span') for heading in h]
# Out:
# [<span class="price-before">65 ر.س</span>,
#  <span class="price-before">60 ر.س</span>,
#  <span class="product-price" dir="ltr"> 38 ر.س</span>,
#  <span class="product-price" dir="ltr"> 60 ر.س</span>,
#  <span class="product-price" dir="ltr"> 15 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 28 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
#  <span class="product-price" dir="ltr"> 35 ر.س</span>,
# ...

# %%
pp=[heading.find("product-price").string for heading in divs1] 
pp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20164\3729760458.py in <module>
# ----> 1 pp=[heading.find("product-price").string for heading in divs1]
#       2 pp
#
# ~\AppData\Local\Temp\ipykernel_20164\3729760458.py in <listcomp>(.0)
# ----> 1 pp=[heading.find("product-price").string for heading in divs1]
#       2 pp
#
# AttributeError: 'NoneType' object has no attribute 'string'

# %%
movies_data = pd.DataFrame()
movies_data['Store Name'] = store_names
movies_data['Price'] = h

# %%
movies_data
# Out:
#                         Store Name                       Price
# 0                      كل شبر بنذر  [ , [65 ر.س], [45 ر.س],  ]
# 1                    ذكي ولكن مشتت  [ , [60 ر.س], [45 ر.س],  ]
# 2                    الامير الصغير           [ , [ 38 ر.س],  ]
# 3            حكايات القط الشقي 1/2           [ , [ 60 ر.س],  ]
# 4                    الأمير الصغير           [ , [ 15 ر.س],  ]
# 5       مذكرات طالب العجلة الثالثة           [ , [ 35 ر.س],  ]
# 6        مذكرات طالب الحقيقة المرة           [ , [ 35 ر.س],  ]
# 7          مذكرات طالب الحظ العاثر           [ , [ 35 ر.س],  ]
# 8        مذكرات طالب القشة الاخيرة           [ , [ 35 ر.س],  ]
# 9          مذكرات طالب جنون المنزل           [ , [ 35 ر.س],  ]
# 10  مذكرات طالب قوانين الاخ الاكبر           [ , [ 35 ر.س],  ]
# 11       مذكرات طالب الرحلة الشاقة           [ , [ 35 ر.س],  ]
# 12       مذكرات طالب الخطة الفاشلة           [ , [ 35 ر.س],  ]
# 13                     مذكرات طالب           [ , [ 28 ر.س],  ]
# ...
