# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://editorial.rottentomatoes.com/guide/best-action-movies-of-2021-ranked/'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.content, 'lxml')

# %%
divs = soup.find_all('div', {'class':'row countdown-item'})
divs
# Out:
# [<div class="row countdown-item" id="row-index-28" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#28</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/the_vault_2021">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/Fq7IFTHNEZfhMAOyGrZe85gX0NQ=/fit-in/180x240/v2/https://resizing.flixster.com/kWz76hXHfg0rIcSd7Ek5efDLTNQ=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzgxMjM4ZjM0LTBjOTctNDgzYS1iOTU2LTI3MmFlZjQ5MDllZC5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/the_vault_2021">The Vault</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny rotten" title="Rotten"></span> <span class="tMeterScore">58%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#28</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>58481% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> Its runtime passes painlessly enough, but <em>The Vault</em>'s slickly engineered thrills are dulled by familiarity.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Freddie Highmore ("The Good Doctor") and Famke Janssen (X-Men) star in this globe-trotting, action-packed thriller following a high-risk heist. When...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/the_vault_2021" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/freddie_highmore">Freddie Highmore</a>, <a class="" href="//www.rottentomatoes.com/celebrity/astrid_berges_firsbey">Astrid Berges-Firsbey</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sam-riley">Sam Riley</a>, <a class="" href="//www.rottentomatoes.com/celebrity/liam_cunningham">Liam Cunningham</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jaume_balaguero">Jaume Balagueró</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-27" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#27</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/the_protege">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/qSglt3j95p94zNzPA734S5AFVPI=/fit-in/180x240/v2/https://resizing.flixster.com/pwDwsPzQdLpRuLVgvgHY0YDAV_s=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzE1YmQwYWIwLTBkOTQtNGE4Ni1hYmIzLTVmNzM1MDRlYWYwMi5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/the_protege">The Protégé</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">62%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#27</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>66397% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> Maggie Q's still waiting for the action movie that really deserves her -- but until then, <em>The Protégé</em> hits just hard enough to satisfy.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Rescued as a child by the legendary assassin Moody (Samuel L. Jackson) and trained in the family business, Anna (Maggie...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/the_protege" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/michael_keaton">Michael Keaton</a>, <a class="" href="//www.rottentomatoes.com/celebrity/maggie_q">Maggie Q</a>, <a class="" href="//www.rottentomatoes.com/celebrity/samuel_l_jackson">Samuel L. Jackson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_rintoul">David Rintoul</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/martin_campbell">Martin Campbell</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-26" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#26</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/those_who_wish_me_dead">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/7gGQ5golxk5fq_jnTb5S57PgQQ4=/fit-in/180x240/v2/https://resizing.flixster.com/RH3xvWUiNYY2JkmZqqKfWSL2lmY=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzM4MmI4NjA0LTgwMDctNDY4MS04ODYxLTFhYTUxOTExZmYzOS5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/those_who_wish_me_dead">Those Who Wish Me Dead</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">62%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#26</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>71674% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> A squarely traditional '90s-style action thriller, <em>Those Who Wish Me Dead</em> is elevated by Taylor Sheridan's propulsive direction.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Oscar winner Jolie ("Girl, Interrupted," the "Maleficent" films) stars as Hannah, a smoke jumper still reeling from the loss of...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/those_who_wish_me_dead" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/angelina_jolie">Angelina Jolie</a>, <a class="" href="//www.rottentomatoes.com/celebrity/finn_little">Finn Little</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1178712-jon_bernthal">Jon Bernthal</a>, <a class="" href="//www.rottentomatoes.com/celebrity/aidan_gillen">Aidan Gillen</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/taylor_sheridan">Taylor Sheridan</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-25" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#25</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/jungle_cruise">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/FG2-cr49z14lvIE3SrpqkWaz2gM=/fit-in/180x240/v2/https://resizing.flixster.com/jAVMCNx-3OTxhXG4MsnOqldFK4w=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzIyY2E4ZTAxLTUwMGItNDQ1My1hNzNiLTZkOGRhNjgyY2Y4ZC5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/jungle_cruise">Jungle Cruise</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">63%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#25</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>78540% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> Its craft isn't quite as sturdy as some of the classic adventures it's indebted to, but <em>Jungle Cruise</em> remains a fun, family-friendly voyage.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Join fan favorites Dwayne Johnson and Emily Blunt for the adventure of a lifetime on Disney's JUNGLE CRUISE, a rollicking...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/jungle_cruise" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/dwayne_johnson">Dwayne Johnson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1163951-emily_blunt">Emily Blunt</a>, <a class="" href="//www.rottentomatoes.com/celebrity/edgar_ramirez">Edgar Ramírez</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jack_whitehall">Jack Whitehall</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jaume_collet_sera">Jaume Collet-Serra</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-24" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#24</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/prisoners_of_the_ghostland">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/WJiMk4kO2HpYjBfLZAp6bfAQrpM=/fit-in/180x240/v2/https://resizing.flixster.com/Ii1qIAlfPZJVHolDeAT7EYYv6IM=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2ZjMDZlYmVjLWM0Y2MtNGJjOS05NTk2LWU0YzlhYTEwOTRkNi5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/prisoners_of_the_ghostland">Prisoners of the Ghostland</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">61%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#24</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>67675% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Prisoners of the Ghostland</em> is far from Sono's most distinctive work, but viewers in the mood for a deliriously gonzo genre mash-up featuring an explosive performance from Nicolas Cage just might have a ball.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> In the treacherous frontier city of Samurai Town, a ruthless bank robber (Nicolas Cage) is sprung from jail by a...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/prisoners_of_the_ghostland" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/nicolas_cage">Nicolas Cage</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sofia_boutella">Sofia Boutella</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nick_cassavetes">Nick Cassavetes</a>, <a class="" href="//www.rottentomatoes.com/celebrity/bill_moseley">Bill Moseley</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/sion_sono">Sion Sono</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-23" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#23</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/the_matrix_resurrections">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/5vgK9sJBN3OojCOJsBHbuWieRZc=/fit-in/180x240/v2/https://resizing.flixster.com/azk7WCNkOsS1Yb2QOZ6nYBMaVZs=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2Q4ZWE4ZTUwLTI5MTMtNDQ5Yi05M2Y5LTVlNWVlNjU5YWRmZC5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/the_matrix_resurrections">The Matrix Resurrections</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">63%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#23</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>79174% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> If it lacks the original's bracingly original craft, <em>The Matrix Resurrections</em> revisits the world of the franchise with wit, a timely perspective, and heart.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> To find out if his reality is a physical or mental construct, Mr. Anderson, aka Neo, will have to choose...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/the_matrix_resurrections" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/keanu_reeves">Keanu Reeves</a>, <a class="" href="//www.rottentomatoes.com/celebrity/carrie_anne_moss">Carrie-Anne Moss</a>, <a class="" href="//www.rottentomatoes.com/celebrity/yahya_abdul_mateen_ii">Yahya Abdul-Mateen II</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jonathan_groff">Jonathan Groff</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/lana_wachowski">Lana Wachowski</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-22" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#22</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/wrath_of_man">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/B64ro53yMHC_Bdp32fcJRen8fsg=/fit-in/180x240/v2/https://flxt.tmsimg.com/assets/p18774021_p_v7_am.jpg" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/wrath_of_man">Wrath of Man</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">67%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#22</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>78333% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> Wrestling just enough stakes out of its thin plot, <em>Wrath of Man</em> sees Guy Ritchie and Jason Statham reunite for a fun, action-packed ride.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> A mysterious and wild-eyed new cash truck security guard (Jason Statham) surprises his coworkers during a heist in which he...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/wrath_of_man" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jason_statham">Jason Statham</a>, <a class="" href="//www.rottentomatoes.com/celebrity/holt_mccallany">Holt McCallany</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jeffrey_donovan">Jeffrey Donovan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/josh_hartnett">Josh Hartnett</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/guy_ritchie">Guy Ritchie</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-21" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#21</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/army_of_the_dead_2021">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/EH5wkjaPq6Zxp_YIegU1wrIpF-M=/fit-in/180x240/v2/https://resizing.flixster.com/lNRldHOBEcz-g1JpWi53eUPtCfA=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2YyN2RiOGJlLTgyYzMtNDI0OS1iNDJiLTlmZWQ3OWNmNjEwOS5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/army_of_the_dead_2021">Army Of The Dead</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">67%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#21</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>79657% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> An ambitious, over-the-top zombie heist mashup, <em>Army of the Dead</em> brings Zack Snyder back to his genre roots with a suitably gory splash.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> From filmmaker Zack Snyder (300, Zack Snyder's Justice League), ARMY OF THE DEAD takes place following a zombie outbreak that...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/army_of_the_dead_2021" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/dave_bautista">Dave Bautista</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ella_purnell">Ella Purnell</a>, <a class="" href="//www.rottentomatoes.com/celebrity/omari_hardwick">Omari Hardwick</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ana-de-la-reguera">Ana de la Reguera</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/zack_snyder">Zack Snyder</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-20" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#20</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/space_sweepers">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/Jbo-7a9XqJaSsvdzytkXwHv3sb4=/fit-in/180x240/v2/https://flxt.tmsimg.com/assets/p19323897_p_v8_aa.jpg" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/space_sweepers">Space Sweepers</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">69%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#20</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>69250% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> As a story, <em>Space Sweepers</em> isn't as adventurous as its star-navigating protagonists -- but relatable characters and impressive effects keep it from drifting out of orbit.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> After snatching a crashed space shuttle in the latest debris chase, Spaceship Victory's crew members find a 7-year-old girl inside....<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/space_sweepers" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/song_joong_ki">Song Joong-ki</a>, <a class="" href="//www.rottentomatoes.com/celebrity/kim_tae_ri">Kim Tae-ri</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jin_seon_kyu">Jin Seon-kyu</a>, <a class="" href="//www.rottentomatoes.com/celebrity/hae_jin_yoo">Yoo Hae-jin</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jo_sung_hee">Jo Sung-hee</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-19" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#19</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/sentinelle">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/yUyHfv5HgPX7n9RYORlgKVdyUpI=/fit-in/180x240/v2/https://flxt.tmsimg.com/assets/p19488594_p_v8_aa.jpg" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/sentinelle">Sentinelle</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">70%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#19</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>33512% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> No consensus yet.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Transferred home after a traumatizing combat mission, a highly trained French soldier uses her lethal skills to hunt down the...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/sentinelle" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/olga_kurylenko">Olga Kurylenko</a>, <a class="" href="//www.rottentomatoes.com/celebrity/michel_biel">Michel Biel</a>, <a class="" href="//www.rottentomatoes.com/celebrity/guillaume_duhesme">Guillaume Duhesme</a>, <a class="" href="//www.rottentomatoes.com/celebrity/andrey_gorlenko">Andrey Gorlenko</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/julien-leclercq">Julien Leclercq</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-18" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#18</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/sentinelle">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/yUyHfv5HgPX7n9RYORlgKVdyUpI=/fit-in/180x240/v2/https://flxt.tmsimg.com/assets/p19488594_p_v8_aa.jpg" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/sentinelle">Sentinelle</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">70%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#18</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>33512% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> No consensus yet.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Transferred home after a traumatizing combat mission, a highly trained French soldier uses her lethal skills to hunt down the...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/sentinelle" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/olga_kurylenko">Olga Kurylenko</a>, <a class="" href="//www.rottentomatoes.com/celebrity/michel_biel">Michel Biel</a>, <a class="" href="//www.rottentomatoes.com/celebrity/guillaume_duhesme">Guillaume Duhesme</a>, <a class="" href="//www.rottentomatoes.com/celebrity/andrey_gorlenko">Andrey Gorlenko</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/julien-leclercq">Julien Leclercq</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-17" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#17</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/zack_snyders_justice_league">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/OR-tKyogv7C81-59N-dn1TN26iw=/fit-in/180x240/v2/https://resizing.flixster.com/50SbC39OF-DRMPtiQIkDvrmV2SI=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzBlOWJiYmU5LTdhMmYtNGU5YS04YmYyLTkwZWMyNDA0ZmZjMC5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/zack_snyders_justice_league">Zack Snyder's Justice League</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">71%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#17</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>84763% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Zack Snyder's Justice League</em> lives up to its title with a sprawling cut that expands to fit the director's vision -- and should satisfy the fans who willed it into existence.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> In ZACK SNYDER'S JUSTICE LEAGUE, determined to ensure Superman's (Henry Cavill) ultimate sacrifice was not in vain, Bruce Wayne (Ben...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/zack_snyders_justice_league" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/ben_affleck">Ben Affleck</a>, <a class="" href="//www.rottentomatoes.com/celebrity/gal-gadot">Gal Gadot</a>, <a class="" href="//www.rottentomatoes.com/celebrity/henry_cavill">Henry Cavill</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jason_momoa">Jason Momoa</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/zack_snyder">Zack Snyder</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-16" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#16</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/boss_level">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/eehG4NfyLhMkCe1X-9goRQCSlD0=/fit-in/180x240/v2/https://resizing.flixster.com/MsNQktP_hfutKgD4mqzpH_C1fio=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2M0NGFhM2JiLTMwMjYtNDQzNS1hOTFjLTk1MTY0NWRjN2YxMi5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/boss_level">Boss Level</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">73%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#16</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>76087% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Boss Level</em> powers up the increasingly crowded time-loop genre with a gleefully over-the-top sci-fi action thriller that revels in its own excess.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Trapped in a time loop that constantly repeats the day of his murder, former special forces agent Roy Pulver (Frank...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/boss_level" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/frank-grillo">Frank Grillo</a>, <a class="" href="//www.rottentomatoes.com/celebrity/naomi_watts">Naomi Watts</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mel_gibson">Mel Gibson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/annabelle-wallis">Annabelle Wallis</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/joe_carnahan">Joe Carnahan</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-15" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#15</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/godzilla_vs_kong">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/wWn6F29BZAZkP7uPcqfeF_C_Oq0=/fit-in/180x240/v2/https://flxt.tmsimg.com/assets/p16193947_p_v8_ak.jpg" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/godzilla_vs_kong">Godzilla vs. Kong</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">75%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#15</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>92703% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> Delivering squarely on its title, <em>Godzilla vs. Kong</em> swats away character development and human drama to deliver all the spectacle you'd expect from giant monsters slugging it out.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Legends collide in "Godzilla vs. Kong" as these mythic adversaries meet in a spectacular battle for the ages, with the...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/godzilla_vs_kong" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/alexander_skarsgard">Alexander Skarsgård</a>, <a class="" href="//www.rottentomatoes.com/celebrity/millie_brown">Millie Bobby Brown</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1177159-rebecca_hall">Rebecca Hall</a>, <a class="" href="//www.rottentomatoes.com/celebrity/brian_tyree_henry">Brian Tyree Henry</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/adam_wingard">Adam Wingard</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-14" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#14</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/shadow_in_the_cloud">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/q4wvftGarB9ySAxv0N-fETNQyQc=/fit-in/180x240/v2/https://resizing.flixster.com/E86097-Fz9Z7Yc7KCNiCWyL0aZY=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzgyYjkwNjA3LThhMzctNDE0YS04ZDRjLTA1Nzc3NDM1NDVjOC5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/shadow_in_the_cloud">Shadow in the Cloud</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">77%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#14</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>82272% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> Part creature feature, part war movie, and part social commentary, <em>Shadow in the Cloud</em> doesn't always blend its ingredients evenly -- but it's frequently pulpy fun.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> In the throes of World War II, Captain Maude Garrett (CHLOË GRACE MORETZ) joins the all-male crew of a B-17...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/shadow_in_the_cloud" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/chloe_grace_moretz">Chloë Grace Moretz</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nick_robinson">Nick Robinson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/beulah_koale">Beulah Koale</a>, <a class="" href="//www.rottentomatoes.com/celebrity/taylor_john_smith">Taylor John Smith</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/roseanne_liang">Roseanne Liang</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-13" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#13</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/black_widow_2021">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/ZYDx61hUk_rrwtOff5oN15BM24s=/fit-in/180x240/v2/https://resizing.flixster.com/UqanC4hHIFolYIKoZ020-YmubCQ=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzRkMWJjZjI2LWE0MDktNDczZC05ZmNiLTIzMTQ0NTE5MGJiMC5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/black_widow_2021">Black Widow</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">79%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#13</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>99779% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Black Widow</em>'s deeper themes are drowned out in all the action, but it remains a solidly entertaining standalone adventure that's rounded out by a stellar supporting cast.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> In Marvel Studios' action-packed spy thriller "Black Widow," Natasha Romanoff aka Black Widow confronts the darker parts of her ledger...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/black_widow_2021" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/scarlett_johansson">Scarlett Johansson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/florence_pugh">Florence Pugh</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_harbour">David Harbour</a>, <a class="" href="//www.rottentomatoes.com/celebrity/rachel_weisz">Rachel Weisz</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/cate_shortland">Cate Shortland</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-12" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#12</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/blood_red_sky">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/SfvOzQ1KJKXG7IN7waZrzKsUu3k=/fit-in/180x240/v2/https://flxt.tmsimg.com/assets/p20186967_p_v13_aa.jpg" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/blood_red_sky">Blood Red Sky</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">81%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#12</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>81500% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Blood Red Sky</em> makes the most of its high-concept vampire story, delivering a fast-paced treat for genre enthusiasts.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> When a group of terrorists hijacks an overnight transatlantic flight, a mysteriously ill woman must unleash a monstrous secret to...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/blood_red_sky" target="_top"> [More]</a></div>
#  <div class="info cast">
# ...
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Raging Fire</em> forsakes character development to go all in on action -- and fortunately, writer-director Benny Chan Chi-Shun and star Donnie Yen are more than capable of delivering the goods.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Bong (Donnie Yen) is a highly respected hardline cop with a long history of success on dangerous cases. However, his...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/raging_fire" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/donnie_yen">Donnie Yen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nicholas_tse">Nicholas Tse</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ray_lui">Ray Lui</a>, <a class="" href="//www.rottentomatoes.com/celebrity/patrick_tam_3">Patrick Tam</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/benny_chan">Benny Chan</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-5" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#5</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/the_suicide_squad">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/TcipLgkU-ralXyxOT-lFoNfHeus=/fit-in/180x240/v2/https://resizing.flixster.com/AogEc-qbCohObFB8SeipbiLZkaU=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzAyYTFmYWFiLTNhYzItNDg5My1iYmExLWJjZDUzNmI3NDc0Mi5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/the_suicide_squad">The Suicide Squad</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">90%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#5</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>107175% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> Enlivened by writer-director James Gunn's singularly skewed vision, <em>The Suicide Squad</em> marks a funny, fast-paced rebound that plays to the source material's violent, anarchic strengths.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Welcome to hell--a.k.a. Belle Reve, the prison with the highest mortality rate in the US of A. Where the worst...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/the_suicide_squad" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/margot_robbie">Margot Robbie</a>, <a class="" href="//www.rottentomatoes.com/celebrity/idris_elba">Idris Elba</a>, <a class="" href="//www.rottentomatoes.com/celebrity/john_cena">John Cena</a>, <a class="" href="//www.rottentomatoes.com/celebrity/viola_davis">Viola Davis</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/james_gunn">James Gunn</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-4" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#4</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/shang_chi_and_the_legend_of_the_ten_rings">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/fcVnofjxajGj4-qsrW07MTWJwog=/fit-in/180x240/v2/https://resizing.flixster.com/bZGWzjLoyj0GXIQj8vs-8y0xMIA=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzY0NWJhN2RhLTg1Y2YtNDBmYS04YjQ0LWI5MWY4NmIwOGRjMy5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/shang_chi_and_the_legend_of_the_ten_rings">Shang-Chi and the Legend of the Ten Rings</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">91%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#4</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>106190% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>Shang-Chi and the Legend of the Ten Rings</em> isn't entirely free of Marvel's familiar formula, but this exciting origin story expands the MCU in more ways than one.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Marvel Studios' "Shang-Chi and The Legend of The Ten Rings" stars Simu Liu as Shang-Chi, who must confront the past...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/shang_chi_and_the_legend_of_the_ten_rings" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/simu_liu">Simu Liu</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nora_lum">Awkwafina</a>, <a class="" href="//www.rottentomatoes.com/celebrity/menger_zhang">Meng'er Zhang</a>, <a class="" href="//www.rottentomatoes.com/celebrity/fala_chen">Fala Chen</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/destin_daniel_cretton">Destin Daniel Cretton</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-3" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#3</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/spider_man_no_way_home">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/ocv7hmFMoAI1MJN3OU_uSSQ6-0k=/fit-in/180x240/v2/https://resizing.flixster.com/8PNiwC2bpe9OecfYZSOVkvYC5vk=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2U5NGM0Y2Q1LTAyYTItNGFjNC1hNWZhLWMzYjJjOTdjMTFhOS5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/spider_man_no_way_home">Spider-Man: No Way Home</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">93%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#3</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>112390% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> A bigger, bolder <em>Spider-Man</em> sequel, <em>No Way Home</em> expands the franchise's scope and stakes without losing sight of its humor and heart.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> For the first time in the cinematic history of Spider-Man, our friendly neighborhood hero's identity is revealed, bringing his Super...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/spider_man_no_way_home" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/tom_holland">Tom Holland</a>, <a class="" href="//www.rottentomatoes.com/celebrity/zendaya">Zendaya</a>, <a class="" href="//www.rottentomatoes.com/celebrity/benedict_cumberbatch">Benedict Cumberbatch</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jacob_batalon">Jacob Batalon</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jon_watts">Jon Watts</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-2" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#2</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/riders_of_justice">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/j7xsQ1HPosqRXhbdIr8jr2fs92I=/fit-in/180x240/v2/https://resizing.flixster.com/5yY5f75iA_i-Y2CotEYxfLT3-qU=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzLzE3NDhmNDFmLWUxYzktNDM4NS05ZjhiLTc3M2E5YzJhZTMwMy5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/riders_of_justice">Riders of Justice</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">96%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#2</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>101588% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> A darkly humorous revenge thriller with satisfying depth and a dash of savory quirk, <em>Riders of Justice</em> makes another compelling case for Mads Mikkelsen as an all-purpose leading man.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> RIDERS OF JUSTICE follows recently-deployed Markus (Mads Mikkelsen), who is forced to return home to care for his teenage daughter...<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/riders_of_justice" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/mads_mikkelsen">Mads Mikkelsen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nikolaj_lie_kaas">Nikolaj Lie Kaas</a>, <a class="" href="//www.rottentomatoes.com/celebrity/andrea_heick_gadeberg">Andrea Heick Gadeberg</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lars_brygmann">Lars Brygmann</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/anders_thomas_jensen">Anders Thomas Jensen</a></div>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="row countdown-item" id="row-index-1" style="padding-left: 10px;">
#  <div class="countdown-index-resposive">#1</div>
#  <div class="col-sm-6 col-full-xs">
#  <a class="article_movie_poster" href="https://www.rottentomatoes.com/m/the_paper_tigers">
#  <div><img alt="" class="article_poster" sborder="" src="https://resizing.flixster.com/ORhOgQwzNr3NBcUWl5l_dnobvO4=/fit-in/180x240/v2/https://resizing.flixster.com/JSdXMZxo0MKRgE2ftO6gYgsG9io=/ems.cHJkLWVtcy1hc3NldHMvbW92aWVzL2YyNjMzZTIxLTY2ZjgtNDVkOC1iYTEwLWUyNzhlODZjZDlmYy5qcGc=" style="border-color: #EEEEEE; border-style: solid; border-width: 1px;"/></div>
#  </a>
#  </div>
#  <div class="col-sm-18 col-full-xs countdown-item-content">
#  <div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/the_paper_tigers">The Paper Tigers</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">98%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#1</div>
#  </div>
#  </div>
#  <div class="row countdown-item-details">
#  <div class="col-sm-24">
#  <div class="info countdown-adjusted-score"><span class="descriptor">Adjusted Score: </span>100077% <span class="glyphicon glyphicon-question-sign" data-html="true" data-original-title="The Adjusted Score comes from a weighted formula (Bayesian) that we use that accounts for variation in the number of reviews per movie." data-placement="top" data-toggle="tooltip" rel="tooltip" title=""></span></div>
#  <div class="info critics-consensus"><span class="descriptor">Critics Consensus:</span> <em>The Paper Tigers</em> blends action, comedy, and heart to produce a fresh martial arts movie with plenty of throwback charm.</div>
#  <div class="info synopsis"><span class="descriptor">Synopsis:</span> Three martial artists--notorious in their prime as "the three tigers"--have grown into middle-aged men one kick from a pulled muscle....<a class="" data-pageheader="" href="https://www.rottentomatoes.com/m/the_paper_tigers" target="_top"> [More]</a></div>
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/alain_uy">Alain Uy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ron_yuan">Ron Yuan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mykel_shannon_jenkins">Mykel Shannon Jenkins</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jae_suh_park_2">Jae Suh Park</a></div>
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/quoc_bao_tran">Quoc Bao Tran</a></div>
#  </div>
#  </div>
#  </div>
#  </div>]

# %%
divs[0].find_all('div', {'class':'row countdown-item-title-bar'})
# Out:
# [<div class="row countdown-item-title-bar">
#  <div class="col-sm-20 col-full-xs" style="height: 100%;">
#  <div class="article_movie_title" style="float: left;">
#  <div><h2><a href="https://www.rottentomatoes.com/m/the_vault_2021">The Vault</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny rotten" title="Rotten"></span> <span class="tMeterScore">58%</span></h2></div>
#  </div>
#  </div>
#  <div class="col-sm-4 col-full-xs" style="height: 100%;">
#  <div class="countdown-index">#28</div>
#  </div>
#  </div>]

# %%
divs[0].find('h2')
# Out:
# <h2><a href="https://www.rottentomatoes.com/m/the_vault_2021">The Vault</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny rotten" title="Rotten"></span> <span class="tMeterScore">58%</span></h2>

# %%
headings = [div.find('h2')for div in divs]
headings
# Out:
# [<h2><a href="https://www.rottentomatoes.com/m/the_vault_2021">The Vault</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny rotten" title="Rotten"></span> <span class="tMeterScore">58%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_protege">The Protégé</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">62%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/those_who_wish_me_dead">Those Who Wish Me Dead</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">62%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/jungle_cruise">Jungle Cruise</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">63%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/prisoners_of_the_ghostland">Prisoners of the Ghostland</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">61%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_matrix_resurrections">The Matrix Resurrections</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">63%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/wrath_of_man">Wrath of Man</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">67%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/army_of_the_dead_2021">Army Of The Dead</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">67%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/space_sweepers">Space Sweepers</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">69%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/sentinelle">Sentinelle</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">70%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/sentinelle">Sentinelle</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">70%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/zack_snyders_justice_league">Zack Snyder's Justice League</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">71%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/boss_level">Boss Level</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">73%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/godzilla_vs_kong">Godzilla vs. Kong</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">75%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/shadow_in_the_cloud">Shadow in the Cloud</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">77%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/black_widow_2021">Black Widow</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">79%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/blood_red_sky">Blood Red Sky</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">81%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/free_guy">Free Guy</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">80%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/copshop">Copshop</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">82%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/nobody_2021">Nobody</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">84%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/no_time_to_die_2021">No Time to Die</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">83%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/below_zero_2021">Bajocero</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny fresh" title="Fresh"></span> <span class="tMeterScore">88%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/raging_fire">Raging Fire</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">91%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_suicide_squad">The Suicide Squad</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">90%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/shang_chi_and_the_legend_of_the_ten_rings">Shang-Chi and the Legend of the Ten Rings</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">91%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/spider_man_no_way_home">Spider-Man: No Way Home</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">93%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/riders_of_justice">Riders of Justice</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">96%</span></h2>,
#  <h2><a href="https://www.rottentomatoes.com/m/the_paper_tigers">The Paper Tigers</a> <span class="subtle start-year">(2020)</span> <span class="icon tiny certified" title="Certified Fresh"></span> <span class="tMeterScore">98%</span></h2>]

# %%
headings[0]
# Out:
# <h2><a href="https://www.rottentomatoes.com/m/the_vault_2021">The Vault</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny rotten" title="Rotten"></span> <span class="tMeterScore">58%</span></h2>

# %%
[heading.find('a') for heading in headings]
# Out:
# [<a href="https://www.rottentomatoes.com/m/the_vault_2021">The Vault</a>,
#  <a href="https://www.rottentomatoes.com/m/the_protege">The Protégé</a>,
#  <a href="https://www.rottentomatoes.com/m/those_who_wish_me_dead">Those Who Wish Me Dead</a>,
#  <a href="https://www.rottentomatoes.com/m/jungle_cruise">Jungle Cruise</a>,
#  <a href="https://www.rottentomatoes.com/m/prisoners_of_the_ghostland">Prisoners of the Ghostland</a>,
#  <a href="https://www.rottentomatoes.com/m/the_matrix_resurrections">The Matrix Resurrections</a>,
#  <a href="https://www.rottentomatoes.com/m/wrath_of_man">Wrath of Man</a>,
#  <a href="https://www.rottentomatoes.com/m/army_of_the_dead_2021">Army Of The Dead</a>,
#  <a href="https://www.rottentomatoes.com/m/space_sweepers">Space Sweepers</a>,
#  <a href="https://www.rottentomatoes.com/m/sentinelle">Sentinelle</a>,
#  <a href="https://www.rottentomatoes.com/m/sentinelle">Sentinelle</a>,
#  <a href="https://www.rottentomatoes.com/m/zack_snyders_justice_league">Zack Snyder's Justice League</a>,
#  <a href="https://www.rottentomatoes.com/m/boss_level">Boss Level</a>,
#  <a href="https://www.rottentomatoes.com/m/godzilla_vs_kong">Godzilla vs. Kong</a>,
#  <a href="https://www.rottentomatoes.com/m/shadow_in_the_cloud">Shadow in the Cloud</a>,
#  <a href="https://www.rottentomatoes.com/m/black_widow_2021">Black Widow</a>,
#  <a href="https://www.rottentomatoes.com/m/blood_red_sky">Blood Red Sky</a>,
#  <a href="https://www.rottentomatoes.com/m/free_guy">Free Guy</a>,
#  <a href="https://www.rottentomatoes.com/m/copshop">Copshop</a>,
#  <a href="https://www.rottentomatoes.com/m/nobody_2021">Nobody</a>,
#  <a href="https://www.rottentomatoes.com/m/no_time_to_die_2021">No Time to Die</a>,
#  <a href="https://www.rottentomatoes.com/m/below_zero_2021">Bajocero</a>,
#  <a href="https://www.rottentomatoes.com/m/raging_fire">Raging Fire</a>,
#  <a href="https://www.rottentomatoes.com/m/the_suicide_squad">The Suicide Squad</a>,
#  <a href="https://www.rottentomatoes.com/m/shang_chi_and_the_legend_of_the_ten_rings">Shang-Chi and the Legend of the Ten Rings</a>,
#  <a href="https://www.rottentomatoes.com/m/spider_man_no_way_home">Spider-Man: No Way Home</a>,
#  <a href="https://www.rottentomatoes.com/m/riders_of_justice">Riders of Justice</a>,
#  <a href="https://www.rottentomatoes.com/m/the_paper_tigers">The Paper Tigers</a>]

# %%
movie_names = [heading.find('a').string for heading in headings] 
movie_names
# Out:
# ['The Vault',
#  'The Protégé',
#  'Those Who Wish Me Dead',
#  'Jungle Cruise',
#  'Prisoners of the Ghostland',
#  'The Matrix Resurrections',
#  'Wrath of Man',
#  'Army Of The Dead',
#  'Space Sweepers',
#  'Sentinelle',
#  'Sentinelle',
#  "Zack Snyder's Justice League",
#  'Boss Level',
#  'Godzilla vs. Kong',
#  'Shadow in the Cloud',
#  'Black Widow',
#  'Blood Red Sky',
#  'Free Guy',
#  'Copshop',
#  'Nobody',
#  'No Time to Die',
#  'Bajocero',
#  'Raging Fire',
#  'The Suicide Squad',
#  'Shang-Chi and the Legend of the Ten Rings',
#  'Spider-Man: No Way Home',
#  'Riders of Justice',
#  'The Paper Tigers']

# %%
headings[0]
# Out:
# <h2><a href="https://www.rottentomatoes.com/m/the_vault_2021">The Vault</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny rotten" title="Rotten"></span> <span class="tMeterScore">58%</span></h2>

# %%
[heading.find('span',class_ = 'subtle start-year') for heading in headings]
# Out:
# [<span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2020)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2021)</span>,
#  <span class="subtle start-year">(2020)</span>,
#  <span class="subtle start-year">(2020)</span>]

# %%
movie_year = [heading.find('span',class_ = 'subtle start-year').string[1:-1] for heading in headings] 
movie_year
# Out:
# ['2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020']

# %%
movie_year=[int(movie_year) for movie_year in movie_year]
movie_year
# Out:
# [2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2021,
#  2020,
#  2020]

# %%
headings[0]
# Out:
# <h2><a href="https://www.rottentomatoes.com/m/the_vault_2021">The Vault</a> <span class="subtle start-year">(2021)</span> <span class="icon tiny rotten" title="Rotten"></span> <span class="tMeterScore">58%</span></h2>

# %%
[heading.find('span',class_ = 'tMeterScore') for heading in headings]
# Out:
# [<span class="tMeterScore">58%</span>,
#  <span class="tMeterScore">62%</span>,
#  <span class="tMeterScore">62%</span>,
#  <span class="tMeterScore">63%</span>,
#  <span class="tMeterScore">61%</span>,
#  <span class="tMeterScore">63%</span>,
#  <span class="tMeterScore">67%</span>,
#  <span class="tMeterScore">67%</span>,
#  <span class="tMeterScore">69%</span>,
#  <span class="tMeterScore">70%</span>,
#  <span class="tMeterScore">70%</span>,
#  <span class="tMeterScore">71%</span>,
#  <span class="tMeterScore">73%</span>,
#  <span class="tMeterScore">75%</span>,
#  <span class="tMeterScore">77%</span>,
#  <span class="tMeterScore">79%</span>,
#  <span class="tMeterScore">81%</span>,
#  <span class="tMeterScore">80%</span>,
#  <span class="tMeterScore">82%</span>,
#  <span class="tMeterScore">84%</span>,
#  <span class="tMeterScore">83%</span>,
#  <span class="tMeterScore">88%</span>,
#  <span class="tMeterScore">91%</span>,
#  <span class="tMeterScore">90%</span>,
#  <span class="tMeterScore">91%</span>,
#  <span class="tMeterScore">93%</span>,
#  <span class="tMeterScore">96%</span>,
#  <span class="tMeterScore">98%</span>]

# %%
movie_rate = [heading.find('span',class_ = 'tMeterScore').string for heading in headings] 
movie_rate
# Out:
# ['58%',
#  '62%',
#  '62%',
#  '63%',
#  '61%',
#  '63%',
#  '67%',
#  '67%',
#  '69%',
#  '70%',
#  '70%',
#  '71%',
#  '73%',
#  '75%',
#  '77%',
#  '79%',
#  '81%',
#  '80%',
#  '82%',
#  '84%',
#  '83%',
#  '88%',
#  '91%',
#  '90%',
#  '91%',
#  '93%',
#  '96%',
#  '98%']

# %%
movie_rate=[rate.strip('%') for rate in movie_rate]
movie_rate
# Out:
# ['58',
#  '62',
#  '62',
#  '63',
#  '61',
#  '63',
#  '67',
#  '67',
#  '69',
#  '70',
#  '70',
#  '71',
#  '73',
#  '75',
#  '77',
#  '79',
#  '81',
#  '80',
#  '82',
#  '84',
#  '83',
#  '88',
#  '91',
#  '90',
#  '91',
#  '93',
#  '96',
#  '98']

# %%
movie_rate=[int(movie_rate) for movie_rate in movie_rate]
movie_rate
# Out:
# [58,
#  62,
#  62,
#  63,
#  61,
#  63,
#  67,
#  67,
#  69,
#  70,
#  70,
#  71,
#  73,
#  75,
#  77,
#  79,
#  81,
#  80,
#  82,
#  84,
#  83,
#  88,
#  91,
#  90,
#  91,
#  93,
#  96,
#  98]

# %%
directors = [div.find('div', class_ = 'info director')for div in divs]
directors
# Out:
# [<div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jaume_balaguero">Jaume Balagueró</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/martin_campbell">Martin Campbell</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/taylor_sheridan">Taylor Sheridan</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jaume_collet_sera">Jaume Collet-Serra</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/sion_sono">Sion Sono</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/lana_wachowski">Lana Wachowski</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/guy_ritchie">Guy Ritchie</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/zack_snyder">Zack Snyder</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jo_sung_hee">Jo Sung-hee</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/julien-leclercq">Julien Leclercq</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/julien-leclercq">Julien Leclercq</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/zack_snyder">Zack Snyder</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/joe_carnahan">Joe Carnahan</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/adam_wingard">Adam Wingard</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/roseanne_liang">Roseanne Liang</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/cate_shortland">Cate Shortland</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/peter_thorwarth">Peter Thorwarth</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/1048166-shawn_levy">Shawn Levy</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/joe_carnahan">Joe Carnahan</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/ilya_naishuller">Ilya Naishuller</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/cary_joji_fukunaga">Cary Joji Fukunaga</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/lluis_quilez">Lluís Quílez</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/benny_chan">Benny Chan</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/james_gunn">James Gunn</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/destin_daniel_cretton">Destin Daniel Cretton</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jon_watts">Jon Watts</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/anders_thomas_jensen">Anders Thomas Jensen</a></div>,
#  <div class="info director">
#  <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/quoc_bao_tran">Quoc Bao Tran</a></div>]

# %%
directors[0]
# Out:
# <div class="info director">
# <span class="descriptor">Directed By:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jaume_balaguero">Jaume Balagueró</a></div>

# %%
[director.find('a').string for director in directors]
# Out:
# ['Jaume Balagueró',
#  'Martin Campbell',
#  'Taylor Sheridan',
#  'Jaume Collet-Serra',
#  'Sion Sono',
#  'Lana Wachowski',
#  'Guy Ritchie',
#  'Zack Snyder',
#  'Jo Sung-hee',
#  'Julien Leclercq',
#  'Julien Leclercq',
#  'Zack Snyder',
#  'Joe Carnahan',
#  'Adam Wingard',
#  'Roseanne Liang',
#  'Cate Shortland',
#  'Peter Thorwarth',
#  'Shawn Levy',
#  'Joe Carnahan',
#  'Ilya Naishuller',
#  'Cary Joji Fukunaga',
#  'Lluís Quílez',
#  'Benny Chan',
#  'James Gunn',
#  'Destin Daniel Cretton',
#  'Jon Watts',
#  'Anders Thomas Jensen',
#  'Quoc Bao Tran']

# %%
directors_name = [director.find('a').string for director in directors]
directors_name
# Out:
# ['Jaume Balagueró',
#  'Martin Campbell',
#  'Taylor Sheridan',
#  'Jaume Collet-Serra',
#  'Sion Sono',
#  'Lana Wachowski',
#  'Guy Ritchie',
#  'Zack Snyder',
#  'Jo Sung-hee',
#  'Julien Leclercq',
#  'Julien Leclercq',
#  'Zack Snyder',
#  'Joe Carnahan',
#  'Adam Wingard',
#  'Roseanne Liang',
#  'Cate Shortland',
#  'Peter Thorwarth',
#  'Shawn Levy',
#  'Joe Carnahan',
#  'Ilya Naishuller',
#  'Cary Joji Fukunaga',
#  'Lluís Quílez',
#  'Benny Chan',
#  'James Gunn',
#  'Destin Daniel Cretton',
#  'Jon Watts',
#  'Anders Thomas Jensen',
#  'Quoc Bao Tran']

# %%
starring = [div.find('div', class_ = 'info cast')for div in divs]
starring
# Out:
# [<div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/freddie_highmore">Freddie Highmore</a>, <a class="" href="//www.rottentomatoes.com/celebrity/astrid_berges_firsbey">Astrid Berges-Firsbey</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sam-riley">Sam Riley</a>, <a class="" href="//www.rottentomatoes.com/celebrity/liam_cunningham">Liam Cunningham</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/michael_keaton">Michael Keaton</a>, <a class="" href="//www.rottentomatoes.com/celebrity/maggie_q">Maggie Q</a>, <a class="" href="//www.rottentomatoes.com/celebrity/samuel_l_jackson">Samuel L. Jackson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_rintoul">David Rintoul</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/angelina_jolie">Angelina Jolie</a>, <a class="" href="//www.rottentomatoes.com/celebrity/finn_little">Finn Little</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1178712-jon_bernthal">Jon Bernthal</a>, <a class="" href="//www.rottentomatoes.com/celebrity/aidan_gillen">Aidan Gillen</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/dwayne_johnson">Dwayne Johnson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1163951-emily_blunt">Emily Blunt</a>, <a class="" href="//www.rottentomatoes.com/celebrity/edgar_ramirez">Edgar Ramírez</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jack_whitehall">Jack Whitehall</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/nicolas_cage">Nicolas Cage</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sofia_boutella">Sofia Boutella</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nick_cassavetes">Nick Cassavetes</a>, <a class="" href="//www.rottentomatoes.com/celebrity/bill_moseley">Bill Moseley</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/keanu_reeves">Keanu Reeves</a>, <a class="" href="//www.rottentomatoes.com/celebrity/carrie_anne_moss">Carrie-Anne Moss</a>, <a class="" href="//www.rottentomatoes.com/celebrity/yahya_abdul_mateen_ii">Yahya Abdul-Mateen II</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jonathan_groff">Jonathan Groff</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/jason_statham">Jason Statham</a>, <a class="" href="//www.rottentomatoes.com/celebrity/holt_mccallany">Holt McCallany</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jeffrey_donovan">Jeffrey Donovan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/josh_hartnett">Josh Hartnett</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/dave_bautista">Dave Bautista</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ella_purnell">Ella Purnell</a>, <a class="" href="//www.rottentomatoes.com/celebrity/omari_hardwick">Omari Hardwick</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ana-de-la-reguera">Ana de la Reguera</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/song_joong_ki">Song Joong-ki</a>, <a class="" href="//www.rottentomatoes.com/celebrity/kim_tae_ri">Kim Tae-ri</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jin_seon_kyu">Jin Seon-kyu</a>, <a class="" href="//www.rottentomatoes.com/celebrity/hae_jin_yoo">Yoo Hae-jin</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/olga_kurylenko">Olga Kurylenko</a>, <a class="" href="//www.rottentomatoes.com/celebrity/michel_biel">Michel Biel</a>, <a class="" href="//www.rottentomatoes.com/celebrity/guillaume_duhesme">Guillaume Duhesme</a>, <a class="" href="//www.rottentomatoes.com/celebrity/andrey_gorlenko">Andrey Gorlenko</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/olga_kurylenko">Olga Kurylenko</a>, <a class="" href="//www.rottentomatoes.com/celebrity/michel_biel">Michel Biel</a>, <a class="" href="//www.rottentomatoes.com/celebrity/guillaume_duhesme">Guillaume Duhesme</a>, <a class="" href="//www.rottentomatoes.com/celebrity/andrey_gorlenko">Andrey Gorlenko</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/ben_affleck">Ben Affleck</a>, <a class="" href="//www.rottentomatoes.com/celebrity/gal-gadot">Gal Gadot</a>, <a class="" href="//www.rottentomatoes.com/celebrity/henry_cavill">Henry Cavill</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jason_momoa">Jason Momoa</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/frank-grillo">Frank Grillo</a>, <a class="" href="//www.rottentomatoes.com/celebrity/naomi_watts">Naomi Watts</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mel_gibson">Mel Gibson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/annabelle-wallis">Annabelle Wallis</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/alexander_skarsgard">Alexander Skarsgård</a>, <a class="" href="//www.rottentomatoes.com/celebrity/millie_brown">Millie Bobby Brown</a>, <a class="" href="//www.rottentomatoes.com/celebrity/1177159-rebecca_hall">Rebecca Hall</a>, <a class="" href="//www.rottentomatoes.com/celebrity/brian_tyree_henry">Brian Tyree Henry</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/chloe_grace_moretz">Chloë Grace Moretz</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nick_robinson">Nick Robinson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/beulah_koale">Beulah Koale</a>, <a class="" href="//www.rottentomatoes.com/celebrity/taylor_john_smith">Taylor John Smith</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/scarlett_johansson">Scarlett Johansson</a>, <a class="" href="//www.rottentomatoes.com/celebrity/florence_pugh">Florence Pugh</a>, <a class="" href="//www.rottentomatoes.com/celebrity/david_harbour">David Harbour</a>, <a class="" href="//www.rottentomatoes.com/celebrity/rachel_weisz">Rachel Weisz</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/graham_mctavish">Graham McTavish</a>, <a class="" href="//www.rottentomatoes.com/celebrity/dominic_purcell">Dominic Purcell</a>, <a class="" href="//www.rottentomatoes.com/celebrity/peri_baumeister">Peri Baumeister</a>, <a class="" href="//www.rottentomatoes.com/celebrity/roland_moller">Roland Møller</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/ryan_reynolds">Ryan Reynolds</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jodie_comer_2">Jodie Comer</a>, <a class="" href="//www.rottentomatoes.com/celebrity/joe_keery">Joe Keery</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lil_rel_howery">Lil Rel Howery</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/gerard_butler">Gerard Butler</a>, <a class="" href="//www.rottentomatoes.com/celebrity/frank-grillo">Frank Grillo</a>, <a class="" href="//www.rottentomatoes.com/celebrity/alexis_louder">Alexis Louder</a>, <a class="" href="//www.rottentomatoes.com/celebrity/toby_huss">Toby Huss</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/bob_odenkirk">Bob Odenkirk</a>, <a class="" href="//www.rottentomatoes.com/celebrity/connie_nielsen">Connie Nielsen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/alexey_serebryakov">Alexey Serebryakov</a>, <a class="" href="//www.rottentomatoes.com/celebrity/christopher_lloyd_2">Christopher Lloyd</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/daniel_craig">Daniel Craig</a>, <a class="" href="//www.rottentomatoes.com/celebrity/rami_malek">Rami Malek</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lea_seydoux">Léa Seydoux</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lashana_lynch">Lashana Lynch</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/javier_gutierrez_2">Javier Gutiérrez</a>, <a class="" href="//www.rottentomatoes.com/celebrity/karra_elejalde">Karra Elejalde</a>, <a class="" href="//www.rottentomatoes.com/celebrity/luis-callejo">Luis Callejo</a>, <a class="" href="//www.rottentomatoes.com/celebrity/patrick_criado">Patrick Criado</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/donnie_yen">Donnie Yen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nicholas_tse">Nicholas Tse</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ray_lui">Ray Lui</a>, <a class="" href="//www.rottentomatoes.com/celebrity/patrick_tam_3">Patrick Tam</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/margot_robbie">Margot Robbie</a>, <a class="" href="//www.rottentomatoes.com/celebrity/idris_elba">Idris Elba</a>, <a class="" href="//www.rottentomatoes.com/celebrity/john_cena">John Cena</a>, <a class="" href="//www.rottentomatoes.com/celebrity/viola_davis">Viola Davis</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/simu_liu">Simu Liu</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nora_lum">Awkwafina</a>, <a class="" href="//www.rottentomatoes.com/celebrity/menger_zhang">Meng'er Zhang</a>, <a class="" href="//www.rottentomatoes.com/celebrity/fala_chen">Fala Chen</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/tom_holland">Tom Holland</a>, <a class="" href="//www.rottentomatoes.com/celebrity/zendaya">Zendaya</a>, <a class="" href="//www.rottentomatoes.com/celebrity/benedict_cumberbatch">Benedict Cumberbatch</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jacob_batalon">Jacob Batalon</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/mads_mikkelsen">Mads Mikkelsen</a>, <a class="" href="//www.rottentomatoes.com/celebrity/nikolaj_lie_kaas">Nikolaj Lie Kaas</a>, <a class="" href="//www.rottentomatoes.com/celebrity/andrea_heick_gadeberg">Andrea Heick Gadeberg</a>, <a class="" href="//www.rottentomatoes.com/celebrity/lars_brygmann">Lars Brygmann</a></div>,
#  <div class="info cast">
#  <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/alain_uy">Alain Uy</a>, <a class="" href="//www.rottentomatoes.com/celebrity/ron_yuan">Ron Yuan</a>, <a class="" href="//www.rottentomatoes.com/celebrity/mykel_shannon_jenkins">Mykel Shannon Jenkins</a>, <a class="" href="//www.rottentomatoes.com/celebrity/jae_suh_park_2">Jae Suh Park</a></div>]

# %%
starring[0]
# Out:
# <div class="info cast">
# <span class="descriptor">Starring:</span> <a class="" href="//www.rottentomatoes.com/celebrity/freddie_highmore">Freddie Highmore</a>, <a class="" href="//www.rottentomatoes.com/celebrity/astrid_berges_firsbey">Astrid Berges-Firsbey</a>, <a class="" href="//www.rottentomatoes.com/celebrity/sam-riley">Sam Riley</a>, <a class="" href="//www.rottentomatoes.com/celebrity/liam_cunningham">Liam Cunningham</a></div>

# %%
[starring.find('a').string for starring in starring]
# Out:
# ['Freddie Highmore',
#  'Michael Keaton',
#  'Angelina Jolie',
#  'Dwayne Johnson',
#  'Nicolas Cage',
#  'Keanu Reeves',
#  'Jason Statham',
#  'Dave Bautista',
#  'Song Joong-ki',
#  'Olga Kurylenko',
#  'Olga Kurylenko',
#  'Ben Affleck',
#  'Frank Grillo',
#  'Alexander Skarsgård',
#  'Chloë Grace Moretz',
#  'Scarlett Johansson',
#  'Graham McTavish',
#  'Ryan Reynolds',
#  'Gerard Butler',
#  'Bob Odenkirk',
#  'Daniel Craig',
#  'Javier Gutiérrez',
#  'Donnie Yen',
#  'Margot Robbie',
#  'Simu Liu',
#  'Tom Holland',
#  'Mads Mikkelsen',
#  'Alain Uy']

# %%
cast_links = starring[0].find_all('a')
cast_links
# Out:
# [<a class="" href="//www.rottentomatoes.com/celebrity/freddie_highmore">Freddie Highmore</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/astrid_berges_firsbey">Astrid Berges-Firsbey</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/sam-riley">Sam Riley</a>,
#  <a class="" href="//www.rottentomatoes.com/celebrity/liam_cunningham">Liam Cunningham</a>]

# %%
cast_name = [link.string for link in cast_links]
cast_name
# Out:
# ['Freddie Highmore', 'Astrid Berges-Firsbey', 'Sam Riley', 'Liam Cunningham']

# %%
cast = ', '.join(cast_name)
cast
# Out:
# 'Freddie Highmore, Astrid Berges-Firsbey, Sam Riley, Liam Cunningham'

# %%
cast = []

for s in starring:
    cast_links = s.find_all('a')
    cast_names = [link.string for link in cast_links]
    cast.append(', '.join(cast_names))

# %%
cast
# Out:
# ['Freddie Highmore, Astrid Berges-Firsbey, Sam Riley, Liam Cunningham',
#  'Michael Keaton, Maggie Q, Samuel L. Jackson, David Rintoul',
#  'Angelina Jolie, Finn Little, Jon Bernthal, Aidan Gillen',
#  'Dwayne Johnson, Emily Blunt, Edgar Ramírez, Jack Whitehall',
#  'Nicolas Cage, Sofia Boutella, Nick Cassavetes, Bill Moseley',
#  'Keanu Reeves, Carrie-Anne Moss, Yahya Abdul-Mateen II, Jonathan Groff',
#  'Jason Statham, Holt McCallany, Jeffrey Donovan, Josh Hartnett',
#  'Dave Bautista, Ella Purnell, Omari Hardwick, Ana de la Reguera',
#  'Song Joong-ki, Kim Tae-ri, Jin Seon-kyu, Yoo Hae-jin',
#  'Olga Kurylenko, Michel Biel, Guillaume Duhesme, Andrey Gorlenko',
#  'Olga Kurylenko, Michel Biel, Guillaume Duhesme, Andrey Gorlenko',
#  'Ben Affleck, Gal Gadot, Henry Cavill, Jason Momoa',
#  'Frank Grillo, Naomi Watts, Mel Gibson, Annabelle Wallis',
#  'Alexander Skarsgård, Millie Bobby Brown, Rebecca Hall, Brian Tyree Henry',
#  'Chloë Grace Moretz, Nick Robinson, Beulah Koale, Taylor John Smith',
#  'Scarlett Johansson, Florence Pugh, David Harbour, Rachel Weisz',
#  'Graham McTavish, Dominic Purcell, Peri Baumeister, Roland Møller',
#  'Ryan Reynolds, Jodie Comer, Joe Keery, Lil Rel Howery',
#  'Gerard Butler, Frank Grillo, Alexis Louder, Toby Huss',
#  'Bob Odenkirk, Connie Nielsen, Alexey Serebryakov, Christopher Lloyd',
#  'Daniel Craig, Rami Malek, Léa Seydoux, Lashana Lynch',
#  'Javier Gutiérrez, Karra Elejalde, Luis Callejo, Patrick Criado',
#  'Donnie Yen, Nicholas Tse, Ray Lui, Patrick Tam',
#  'Margot Robbie, Idris Elba, John Cena, Viola Davis',
#  "Simu Liu, Awkwafina, Meng'er Zhang, Fala Chen",
#  'Tom Holland, Zendaya, Benedict Cumberbatch, Jacob Batalon',
#  'Mads Mikkelsen, Nikolaj Lie Kaas, Andrea Heick Gadeberg, Lars Brygmann',
#  'Alain Uy, Ron Yuan, Mykel Shannon Jenkins, Jae Suh Park']

# %%
cast

# %%
import pandas as pd

# %%
movies_data = pd.DataFrame()

# %%
movies_data['Title'] = movie_names
movies_data['Year'] = movie_year
movies_data['Rate'] = movie_rate
movies_data['Directors'] = directors_name
movies_data['Cast'] = cast
movies_data
# Out:
#                                         Title  Year  Rate  \
# 0                                   The Vault  2021    58
# 1                                 The Protégé  2021    62
# 2                      Those Who Wish Me Dead  2021    62
# 3                               Jungle Cruise  2021    63
# 4                  Prisoners of the Ghostland  2021    61
# 5                    The Matrix Resurrections  2021    63
# 6                                Wrath of Man  2021    67
# 7                            Army Of The Dead  2021    67
# 8                              Space Sweepers  2021    69
# 9                                  Sentinelle  2021    70
# 10                                 Sentinelle  2021    70
# 11               Zack Snyder's Justice League  2021    71
# 12                                 Boss Level  2021    73
# 13                          Godzilla vs. Kong  2021    75
# 14                        Shadow in the Cloud  2020    77
# 15                                Black Widow  2021    79
# 16                              Blood Red Sky  2021    81
# 17                                   Free Guy  2021    80
# 18                                    Copshop  2021    82
# 19                                     Nobody  2021    84
# 20                             No Time to Die  2021    83
# 21                                   Bajocero  2021    88
# 22                                Raging Fire  2021    91
# 23                          The Suicide Squad  2021    90
# 24  Shang-Chi and the Legend of the Ten Rings  2021    91
# 25                    Spider-Man: No Way Home  2021    93
# 26                          Riders of Justice  2020    96
# 27                           The Paper Tigers  2020    98
#
#                 Directors                                               Cast
# 0         Jaume Balagueró  Freddie Highmore, Astrid Berges-Firsbey, Sam R...
# 1         Martin Campbell  Michael Keaton, Maggie Q, Samuel L. Jackson, D...
# 2         Taylor Sheridan  Angelina Jolie, Finn Little, Jon Bernthal, Aid...
# 3      Jaume Collet-Serra  Dwayne Johnson, Emily Blunt, Edgar Ramírez, Ja...
# 4               Sion Sono  Nicolas Cage, Sofia Boutella, Nick Cassavetes,...
# 5          Lana Wachowski  Keanu Reeves, Carrie-Anne Moss, Yahya Abdul-Ma...
# 6             Guy Ritchie  Jason Statham, Holt McCallany, Jeffrey Donovan...
# 7             Zack Snyder  Dave Bautista, Ella Purnell, Omari Hardwick, A...
# 8             Jo Sung-hee  Song Joong-ki, Kim Tae-ri, Jin Seon-kyu, Yoo H...
# 9         Julien Leclercq  Olga Kurylenko, Michel Biel, Guillaume Duhesme...
# 10        Julien Leclercq  Olga Kurylenko, Michel Biel, Guillaume Duhesme...
# 11            Zack Snyder  Ben Affleck, Gal Gadot, Henry Cavill, Jason Momoa
# 12           Joe Carnahan  Frank Grillo, Naomi Watts, Mel Gibson, Annabel...
# 13           Adam Wingard  Alexander Skarsgård, Millie Bobby Brown, Rebec...
# 14         Roseanne Liang  Chloë Grace Moretz, Nick Robinson, Beulah Koal...
# 15         Cate Shortland  Scarlett Johansson, Florence Pugh, David Harbo...
# 16        Peter Thorwarth  Graham McTavish, Dominic Purcell, Peri Baumeis...
# 17             Shawn Levy  Ryan Reynolds, Jodie Comer, Joe Keery, Lil Rel...
# 18           Joe Carnahan  Gerard Butler, Frank Grillo, Alexis Louder, To...
# 19        Ilya Naishuller  Bob Odenkirk, Connie Nielsen, Alexey Serebryak...
# 20     Cary Joji Fukunaga  Daniel Craig, Rami Malek, Léa Seydoux, Lashana...
# 21           Lluís Quílez  Javier Gutiérrez, Karra Elejalde, Luis Callejo...
# 22             Benny Chan     Donnie Yen, Nicholas Tse, Ray Lui, Patrick Tam
# 23             James Gunn  Margot Robbie, Idris Elba, John Cena, Viola Davis
# 24  Destin Daniel Cretton      Simu Liu, Awkwafina, Meng'er Zhang, Fala Chen
# 25              Jon Watts  Tom Holland, Zendaya, Benedict Cumberbatch, Ja...
# 26   Anders Thomas Jensen  Mads Mikkelsen, Nikolaj Lie Kaas, Andrea Heick...
# 27          Quoc Bao Tran  Alain Uy, Ron Yuan, Mykel Shannon Jenkins, Jae...

# %%
# to save dataframe pandas as file csv
mov = ["Cast", "Rate", "Year", "Title","Directors"]
 
# dictionary of lists
dict = {'movv': mov}
     
df = pd.DataFrame(dict)
 
print(df)
# Out:
#         movv
# 0       Cast
# 1       Rate
# 2       Year
# 3      Title
# 4  Directors

# %%
df.to_csv('file1.csv')
df
# Out:
#         movv
# 0       Cast
# 1       Rate
# 2       Year
# 3      Title
# 4  Directors

# %%
df.to_csv('file2.csv', header=False, index=False)

# %%
df.to_csv(r'C:\Users\Faris\Desktop\file3.csv')

# %%
df = pd.read_csv('file1.csv')

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      28 non-null     object
#  1   Year       28 non-null     int64
#  2   Rate       28 non-null     int64
#  3   Directors  28 non-null     object
#  4   Cast       28 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 1.2+ KB

# %%
movies_data.isnull().sum()
# Out:
# Title        0
# Year         0
# Rate         0
# Directors    0
# Cast         0
# dtype: int64

# %%
movies_data.head()
# Out:
#                         Title  Year  Rate           Directors  \
# 0                   The Vault  2021    58     Jaume Balagueró
# 1                 The Protégé  2021    62     Martin Campbell
# 2      Those Who Wish Me Dead  2021    62     Taylor Sheridan
# 3               Jungle Cruise  2021    63  Jaume Collet-Serra
# 4  Prisoners of the Ghostland  2021    61           Sion Sono
#
#                                                 Cast
# 0  Freddie Highmore, Astrid Berges-Firsbey, Sam R...
# 1  Michael Keaton, Maggie Q, Samuel L. Jackson, D...
# 2  Angelina Jolie, Finn Little, Jon Bernthal, Aid...
# 3  Dwayne Johnson, Emily Blunt, Edgar Ramírez, Ja...
# 4  Nicolas Cage, Sofia Boutella, Nick Cassavetes,...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %%
sns.barplot(data=movies_data,x='Year', y="Rate").set_title('relationship between year and rate')
# Out:
# Text(0.5, 1.0, 'relationship between year and rate')

# %% [markdown]
# ###### notice the 2020 the over 80
# ##### and in 2021 the rate almost 70

# %%
movies_data.head()
# Out:
#                         Title  Year  Rate           Directors  \
# 0                   The Vault  2021    58     Jaume Balagueró
# 1                 The Protégé  2021    62     Martin Campbell
# 2      Those Who Wish Me Dead  2021    62     Taylor Sheridan
# 3               Jungle Cruise  2021    63  Jaume Collet-Serra
# 4  Prisoners of the Ghostland  2021    61           Sion Sono
#
#                                                 Cast
# 0  Freddie Highmore, Astrid Berges-Firsbey, Sam R...
# 1  Michael Keaton, Maggie Q, Samuel L. Jackson, D...
# 2  Angelina Jolie, Finn Little, Jon Bernthal, Aid...
# 3  Dwayne Johnson, Emily Blunt, Edgar Ramírez, Ja...
# 4  Nicolas Cage, Sofia Boutella, Nick Cassavetes,...

# %%
#sns.lineplot(data=movies_data, x="Year", y="Title")
#sns.histplot(movies_data, y="Rate")
sns.countplot(data=movies_data, y="Rate").set_title('count the rate')
# Out:
# Text(0.5, 1.0, 'count the rate')

# %% [markdown]
# ##### notice in 62,63,67 ,70 and 91 the the rate is equal

# %%
sns.countplot(data=movies_data, x="Year").set_title('compare the movie in 2020 and 2021')
# Out:
# Text(0.5, 1.0, 'compare the movie in 2020 and 2021')

# %% [markdown]
# ### the action movies in 2021 more than 2020
# ### and notice the rate in 2021 increased by more than 70%
