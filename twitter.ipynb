# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('TwitterData.csv')
dataset
# Out:
#       Unnamed: 0           User                           Name Date Created  \
# 0              0     thinkin_ca                        ThinkIn   2023-02-15
# 1              1    hackathonat                      هاكاثونات   2023-02-14
# 2              2        DevJood                Jood | جود 👩🏻‍💻   2023-02-14
# 3              3  lina_alismail  لينا السماعيل | Lina Alismail   2023-02-14
# 4              4       mkii3216                       َالسعودي   2023-02-13
# ...          ...            ...                            ...          ...
# 1587        1656    ShafaqeNews          صحيفة شفق الإلكترونية   2022-05-21
# 1588        1657     jobs2saudi             وظائف للسعوديين 🇸🇦   2022-05-21
# 1589        1658         ewdifh               وظائف | أي وظيفة   2022-05-21
# 1590        1659     MoraIPanlc                             Aj   2022-05-18
# 1591        1660    PotterSaudi                   saudi potter   2022-04-11
#
#       Number of Likes      Source of Tweet  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       1592 non-null   int64
#  1   User             1592 non-null   object
#  2   Name             1592 non-null   object
#  3   Date Created     1592 non-null   object
#  4   Number of Likes  1592 non-null   int64
#  5   Source of Tweet  1592 non-null   object
#  6   Tweet            1592 non-null   object
#  7   Language         1592 non-null   object
#  8   Coordinates      13 non-null     object
#  9   place            13 non-null     object
#  10  cleanTweet       1592 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 136.9+ KB

# %% [markdown]
# ## Missing value

# %%
dataset.notnull().sum()
# Out:
# Unnamed: 0         1592
# User               1592
# Name               1592
# Date Created       1592
# Number of Likes    1592
# Source of Tweet    1592
# Tweet              1592
# Language           1592
# Coordinates          13
# place                13
# cleanTweet         1592
# dtype: int64

# %%
null = pd.notnull(dataset["place"])
dataset[null]
# Out:
#       Unnamed: 0            User                           Name Date Created  \
# 486          508        7amoodi6                    محمد حدائدي   2022-08-10
# 521          546       Saad_abdk                سعد العبدالكريم   2022-08-09
# 574          599    aminah_baksh       أمينه بخش/ الأميره أضواء   2022-08-09
# 590          615         Hno0onh                   حنان صالح 🇸🇦   2022-08-09
# 591          616         Hno0onh                   حنان صالح 🇸🇦   2022-08-09
# 592          617         Hno0onh                   حنان صالح 🇸🇦   2022-08-09
# 628          655   lina_alismail  لينا السماعيل | Lina Alismail   2022-08-08
# 774          809      AlaaMulla1                  علاء الملا ✪‏   2022-08-07
# 841          878        esamway2                   عصام الدميني   2022-08-07
# 1023        1066   Mohammed91918                Mohammed ﮼١٧٢٧م   2022-08-07
# 1345        1413  turki_alrsheed                    تركي الرشيد   2022-08-07
# ...

# %%
dataset.drop(['Unnamed: 0','Coordinates','place'], axis=1, inplace=True)

# %% [markdown]
# ## Duplicates

# %%
dataset.drop_duplicates()
# Out:
#                User                           Name Date Created  \
# 0        thinkin_ca                        ThinkIn   2023-02-15
# 1       hackathonat                      هاكاثونات   2023-02-14
# 2           DevJood                Jood | جود 👩🏻‍💻   2023-02-14
# 3     lina_alismail  لينا السماعيل | Lina Alismail   2023-02-14
# 4          mkii3216                       َالسعودي   2023-02-13
# ...             ...                            ...          ...
# 1587    ShafaqeNews          صحيفة شفق الإلكترونية   2022-05-21
# 1588     jobs2saudi             وظائف للسعوديين 🇸🇦   2022-05-21
# 1589         ewdifh               وظائف | أي وظيفة   2022-05-21
# 1590     MoraIPanlc                             Aj   2022-05-18
# 1591    PotterSaudi                   saudi potter   2022-04-11
#
#       Number of Likes      Source of Tweet  \
# 0                   0   Twitter for iPhone
# 1                   3   Twitter for iPhone
# 2                   2   Twitter for iPhone
# ...

# %%
dataset['Number of Likes'].
# Out:
# 4267

# %%
group = dataset[['Tweet','Number of Likes']].groupby('Tweet').max()[:5]
group
# Out:
#                                                     Number of Likes
# Tweet
# "احتفلت أكاديمية مطوري أبل النسائية، بتخريج ١٠٣...                3
# "فخر لا يوصف" هكذا عبّر والد الخريجة رنين عن مش...              181
# "من تَرَك مَلَك"\n\n #اكاديميه_مطوري_ابل                          0
# #Apple_developer \n#اكاديمية_مطوري_ابل \n كانت ...                1
# #KSA - (#السعودية) تأهل فريقان سعوديان من أكادي...                4

# %%
plt.hist(dataset['Number of Likes'])

plt.xlabel('Number of Likes')
plt.ylabel('Frequency')
plt.title('Number of Likes')

plt.show()
